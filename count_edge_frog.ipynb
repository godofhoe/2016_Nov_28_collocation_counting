# %% [markdown]
# ## Using count_edge function to count the total number of edges between words in the novel 'Frog'

# %%
import random 
import bisect 
import math 
from functools import reduce
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from count import *
from count_col import count_col
# %matplotlib inline

# %%
#encode = "UTF-16" #(1)
encode = "UTF-8"   #(2)
##if anything gets into trouble, use (1) instead of (2), and vise versa.
filename = 'frog.txt' #change filename if you want to get statictical information of another
##text file.
big, char, word = main(filename,encode)
# Out:
# read file successfully!
# Successfully count word freqency!
# Successfully count char freqency!
# Successfully build data frames!

# %%
count_edge(word)
word.to_csv('out1.csv', sep=',')

# %%
word
# Out:
#        word  wordFreq  wordRank  wordSeqOrder  #edges
# 0         的      5873         1             2      15
# 1         我      3454         2            13       6
# 2         了      2564         3            87      34
# 3         是      1954         4           166      33
# 4         一      1925         5           122     175
# 5         著      1562         6           125      44
# 6         你      1405         7           984       6
# 7         說      1368         8           105      51
# 8         個      1355         9           123      26
# 9        姑姑      1184        10            93      12
# 10        在      1121        11            12      29
# 11        他      1114        12           197       9
# 12        不      1002        13           195     236
# 13        她       974        14            96       2
# 14        這       960        15            27      11
# 15        那       909        16            67       9
# 16        上       711        17            64     201
# 17       我們       699        18            38      34
# 18        也       679        19            74       6
# 19        就       678        20           287      13
# 20        地       648        21           678     111
# 21        有       636        22           121      74
# 22        都       518        23           329       6
# 23        小       501        24           505     123
# 24        人       478        25           185     242
# 25        但       466        26             9       4
# 26        把       435        27           208      12
# 27       孩子       432        28           358     287
# 28        裏       427        29           120      88
# 29        要       366        30           233      23
# ...     ...       ...       ...           ...     ...
# 14350  半夜三更         1     14351         14346     102
# 14351   起作用         1     14352         14348     191
# 14352    中藥         1     14353         14349      79
# 14353    總賬         1     14354         14350      15
# 14354  夜深人靜         1     14355         14351     303
# 14355    號哭         1     14356         14352      45
# 14356    少爪         1     14357         14353      25
# 14357    混成         1     14358         14354      98
# 14358  蛙鬼們魘         1     14359         14355      70
# 14359    道士         1     14360         14356      66
# 14360    禳解         1     14361         14357      31
# 14361     惡         1     14362         14358      21
# 14362    自責         1     14363         14361      64
# 14363    投票         1     14364         14362      28
# 14364    選舉         1     14365         14363      14
# 14365    得票         1     14366         14364      64
# 14366   臭娘們         1     14367         14365      60
# 14367  神采飛揚         1     14368         14366     102
# 14368    說錯         1     14369         14367      61
# 14369    煎熬         1     14370         14368       8
# 14370    煎魚         1     14371         14369      37
# 14371    地煎         1     14372         14370     115
# 14372    熬藥         1     14373         14371      24
# 14373   罪贖完         1     14374         14372      59
# 14374    垂下         1     14375         14373     179
# 14375    頸子         1     14376         14374     278
# 14376    套進         1     14377         14375      70
# 14377    踢翻         1     14378         14376      27
# 14378    砍斷         1     14379         14378      34
# 14379    劇終         1     14380         14380      27
#
# [14380 rows x 5 columns]

# %%
print("Total number of edges: " + str(word['#edges'].sum()))
# Out:
# Total number of edges: 1185904
